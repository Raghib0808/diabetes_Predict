# %%
import numpy as py

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes=pd.read_csv('diabetes.csv')

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import matplotlib

# %%
import matplotlib
plt.figure(figsize=(10,6))
plt.title("Relation between pregnancies and Diabetes")
sns.barplot(x='Pregnancies',y='Glucose',data=diabetes,palette='inferno')
plt.show()

# %%
from scipy import stats

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
plt.title("Relation between BMI and Diabetes")

sns.boxplot(x='Outcome',y='BMI',data=diabetes)
# Out:
# <AxesSubplot: title={'center': 'Relation between BMI and Diabetes'}, xlabel='Outcome', ylabel='BMI'>

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
plt.title("Relation between BloodPressure and Diabetes")

sns.boxplot(x='Outcome',y='BloodPressure',data=diabetes)
# Out:
# <AxesSubplot: title={'center': 'Relation between BloodPressure and Diabetes'}, xlabel='Outcome', ylabel='BloodPressure'>

# %%
Nodib=diabetes[diabetes.Outcome==1]
Nodib
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome  boolean
# 0                       0.627   50        1     True
# ...

# %%
dib=diabetes[diabetes.Outcome==0]
dib
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  boolean
# 1                       0.351   31        0    False
# ...

# %%
corr_mat_diabetes=diabetes.corr().round(3)
corr_mat_diabetes
# Out:
#                           Pregnancies  Glucose  BloodPressure  SkinThickness  \
# Pregnancies                     1.000    0.129          0.141         -0.082
# Glucose                         0.129    1.000          0.153          0.057
# BloodPressure                   0.141    0.153          1.000          0.207
# SkinThickness                  -0.082    0.057          0.207          1.000
# Insulin                        -0.074    0.331          0.089          0.437
# BMI                             0.018    0.221          0.282          0.393
# DiabetesPedigreeFunction       -0.034    0.137          0.041          0.184
# Age                             0.544    0.264          0.240         -0.114
# Outcome                         0.222    0.467          0.065          0.075
# boolean                         0.222    0.467          0.065          0.075
#
#                           Insulin    BMI  DiabetesPedigreeFunction    Age  \
# ...

# %%
dib
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  boolean
# 1                       0.351   31        0    False
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(diabetes.corr().round(3),annot=True)
plt.title('Representation in matrix form')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
